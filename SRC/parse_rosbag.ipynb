# %% [markdown]
# # Parsing a rosbag file to work with ct_icp

# %%
import bagpy
from bagpy import bagreader
import os

# %%
b = bagreader(os.path.join("data", "16-mcity1.bag"))
b.topic_table
# Out:
# [INFO]  Data folder data\16-mcity1 already exists. Not creating.
#                                  Topics                                 Types  \
# 0           /costmap_2d/costmap/costmap                nav_msgs/OccupancyGrid
# 1   /costmap_2d/costmap/costmap_updates          map_msgs/OccupancyGridUpdate
# 2         /costmap_2d/costmap/footprint          geometry_msgs/PolygonStamped
# 3                        /current_route                       bolt_msgs/Route
# 4       /dynamic_objects/object_markers        visualization_msgs/MarkerArray
# 5              /dynamic_objects/objects           bolt_msgs/DynamicObjectList
# 6                             /ekf_path                         nav_msgs/Path
# 7               /front_camera/image_raw                     sensor_msgs/Image
# 8          /global_planner/global_route                       bolt_msgs/Route
# 9                              /gps/fix                 sensor_msgs/NavSatFix
# ...
